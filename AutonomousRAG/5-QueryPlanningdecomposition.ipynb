# %% [markdown]
# ### 🧠 What is Query Planning and Decomposition?
# Query Planning and Decomposition is a technique where a complex user query is broken down into simpler sub-questions or tasks, allowing a system (like a RAG agent) to:
#
# - Understand the question more deeply
# - Retrieve more precise and complete information
# - Execute step-by-step reasoning
#
# It's like reverse-engineering a question into manageable steps before answering.
#
# 🧠 What's New in This Version?
# - ✅ Add a Query Planner Node
# - ✅ Break complex user queries into sub-questions
# - ✅ Retrieve docs per sub-question
# - ✅ Combine all retrieved contexts
# - ✅ Generate a final consolidated answer

# %%
import os
from typing import List
from pydantic import BaseModel
from langchain_core.documents import Document
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import FAISS
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langgraph.graph import StateGraph, END
from langchain_huggingface import HuggingFaceEmbeddings
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
import os
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
load_dotenv()

llm=init_chat_model("groq:openai/gpt-oss-20b")

# %%
# ----------------------------
# 1. Load and Embed Documents
# ----------------------------
urls = [
    "https://lilianweng.github.io/posts/2023-06-23-agent/",
    "https://lilianweng.github.io/posts/2024-04-12-diffusion-video/"
]
docs = []
for url in urls:
    docs.extend(WebBaseLoader(url).load())

splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
chunks = splitter.split_documents(docs)

embedding = HuggingFaceEmbeddings()
vectorstore = FAISS.from_documents(chunks, embedding)
retriever = vectorstore.as_retriever()

# %%
# ----------------------------
# 2. State Schema
# ----------------------------
class RAGState(BaseModel):
    question: str
    sub_questions: List[str] = []
    retrieved_docs: List[Document] = []
    answer: str = ""

# %%
# ----------------------------
# 3. Nodes
# ----------------------------

## a. Query Planner: splits input question
def plan_query(state: RAGState) -> RAGState:
   
    prompt = f"""
Break the following complex question into 2-3 sub-questions. Write each question in a separate line separated by new line characters:

Question: {state.question}

Sub-questions:
"""
    result = llm.invoke(prompt)
    sub_questions = [line.strip("- ").strip() for line in result.content.strip().split("\n") if line.strip()]
    return RAGState(question=state.question, sub_questions=sub_questions)

## b. Retrieve documents for each sub-question
def retrieve_for_each(state: RAGState) -> RAGState:
    all_docs = []
    for sub in state.sub_questions:
        docs = retriever.invoke(sub)
        all_docs.extend(docs)
    return RAGState(question=state.question, sub_questions=state.sub_questions, retrieved_docs=all_docs)

## c. Generate final answer
def generate_final_answer(state: RAGState) -> RAGState:
    context = "\n\n".join([doc.page_content for doc in state.retrieved_docs])
    prompt = f"""
Use the context below to answer the question.

Context:
{context}

Question: {state.question}
"""
    
    answer = llm.invoke(prompt).content
    return RAGState(question=state.question, sub_questions=state.sub_questions, retrieved_docs=state.retrieved_docs, answer=answer)

# %%
# ----------------------------
# 4. Build LangGraph
# ----------------------------
builder = StateGraph(RAGState)

builder.add_node("planner", plan_query)
builder.add_node("retriever", retrieve_for_each)
builder.add_node("responder", generate_final_answer)

builder.set_entry_point("planner")
builder.add_edge("planner", "retriever")
builder.add_edge("retriever", "responder")
builder.add_edge("responder", END)

graph = builder.compile()
graph

# %%
graph

# %%
# ----------------------------
# 5. Run the pipeline
# ----------------------------
if __name__ == "__main__":
    user_query = "Explain how agent loops work and what are the challenges in diffusion video generation?"
    initial_state = RAGState(question=user_query)
    final_state = graph.invoke(initial_state)
    print(final_state)

    print("\n🔍 Sub-questions:")
    for q in final_state['sub_questions']:
        print("-", q)

    print("\n✅ Final Answer:\n", final_state['answer'])
# Out:
# {'question': 'Explain how agent loops work and what are the challenges in diffusion video generation?', 'sub_questions': ['How do agent loops function within the context of diffusion models for video generation?', 'What specific technical or computational challenges arise when applying diffusion models to video generation?', 'How do these challenges impact the quality, efficiency, or feasibility of generating videos using diffusion techniques?'], 'retrieved_docs': [Document(id='fd9dc095-d74f-4d67-8fe8-6f4ff4645143', metadata={'source': 'https://lilianweng.github.io/posts/2024-04-12-diffusion-video/', 'title': "Diffusion Models for Video Generation | Lil'Log", 'description': 'Diffusion models have demonstrated strong results on image synthesis in past years. Now the research community has started working on a harder task—using it for video generation. The task itself is a superset of the image case, since an image is a video of 1 frame, and it is much more challenging because:\n\nIt has extra requirements on temporal consistency across frames in time, which naturally demands more world knowledge to be encoded into the model.\nIn comparison to text or images, it is more difficult to collect large amounts of high-quality, high-dimensional video data, let along text-video pairs.\n\n\n\n🥑 Required Pre-read: Please make sure you have read the previous blog on “What are Diffusion Models?” for image generation before continue here.\n', 'language': 'en'}, page_content="Diffusion Models for Video Generation | Lil'Log\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLil'Log\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n|\n\n\n\n\n\n\nPosts\n\n\n\n\nArchive\n\n\n\n\nSearch\n\n\n\n\nTags\n\n\n\n\nFAQ\n\n\n\n\n\n\n\n\n\n      Diffusion Models for Video Generation\n    \nDate: April 12, 2024  |  Estimated Reading Time: 20 min  |  Author: Lilian Weng\n\n\n \n\n\nTable of Contents\n\n\n\nVideo Generation Modeling from Scratch\n\nParameterization & Sampling Basics\n\nModel Architecture: 3D U-Net & DiT\n\n\nAdapting Image Models to Generate Videos"), Document(id='db32d2c7-4e3f-4d04-86da-f4a1d9a58ab2', metadata={'source': 'https://lilianweng.github.io/posts/2024-04-12-diffusion-video/', 'title': "Diffusion Models for Video Generation | Lil'Log", 'description': 'Diffusion models have demonstrated strong results on image synthesis in past years. Now the research community has started working on a harder task—using it for video generation. The task itself is a superset of the image case, since an image is a video of 1 frame, and it is much more challenging because:\n\nIt has extra requirements on temporal consistency across frames in time, which naturally demands more world knowledge to be encoded into the model.\nIn comparison to text or images, it is more difficult to collect large amounts of high-quality, high-dimensional video data, let along text-video pairs.\n\n\n\n🥑 Required Pre-read: Please make sure you have read the previous blog on “What are Diffusion Models?” for image generation before continue here.\n', 'language': 'en'}, page_content='The overview of ControlVideo. (Image source: Zhang et al. 2023)\n\nCitation#\nCited as:\n\nWeng, Lilian. (Apr 2024). Diffusion Models Video Generation. Lil’Log. https://lilianweng.github.io/posts/2024-04-12-diffusion-video/.'), Document(id='f5d91d21-0f7e-4478-a383-5848f9995270', metadata={'source': 'https://lilianweng.github.io/posts/2024-04-12-diffusion-video/', 'title': "Diffusion Models for Video Generation | Lil'Log", 'description': 'Diffusion models have demonstrated strong results on image synthesis in past years. Now the research community has started working on a harder task—using it for video generation. The task itself is a superset of the image case, since an image is a video of 1 frame, and it is much more challenging because:\n\nIt has extra requirements on temporal consistency across frames in time, which naturally demands more world knowledge to be encoded into the model ...
#
# 🔍 Sub-questions:
# - How do agent loops function within the context of diffusion models for video generation?
# - What specific technical or computational challenges arise when applying diffusion models to video generation?
# - How do these challenges impact the quality, efficiency, or feasibility of generating videos using diffusion techniques?
#
# ✅ Final Answer:
#  **Agent loops in diffusion‑video generation**
#
# In a diffusion‑video model the “agent” is the diffusion sampler itself – the iterative process that progressively denoises a random tensor until it becomes a realistic video.
# An *agent loop* is simply the repeated execution of the following cycle:
#
# 1. **Start state** – a noisy latent (or pixel‑level) video is sampled from a Gaussian prior.
# 2. **Conditioning** – the agent receives extra signals that guide the denoising.
#    * *Video‑to‑video*: a previously generated clip (or a low‑framerate version) is fed as a conditioning tensor.
#    * *Text‑to‑video*: a text prompt is embedded and injected into the model (e.g., via cross‑attention).
#    * *Control signals*: pose, depth, motion‑vectors, or any user‑supplied “control” tensor.
# 3. **Denoising step** – the model predicts the noise component for the current timestep and subtracts it, producing a cleaner video tensor.
# 4. **Optional refinement** – a secondary network (e.g., a 3‑D U‑Net or a DiT) can be run on the intermediate output to enforce temporal smoothness or spatial detail.
# 5. **Loop** – the new latent is fed back as the input for the next timestep, until the final timestep \(t=0\) is reached.
#
# Because each step depends on the previous one, the loop is *autoregressive* in time: the agent can generate a short clip, then feed that clip back into itself to grow the video, or it can take a low‑fps clip and “fill in” missing frames by conditioning on the known frames.
#
# ---
#
# ### Key challenges for diffusion‑video generation
#
# | Challenge | Why it matters | Typical workarounds |
# |-----------|----------------|---------------------|
# | **High dimensionality** | A video tensor \( (T, H, W, C) \) is orders of magnitude larger than an image. | Use latent‑space diffusion (e.g., VQ‑VAE or Stable Diffusion’s latent space) to reduce memory; employ 3‑D convolutional blocks that factor spatial and temporal dimensions. |
# | **Temporal consistency** | Small changes between consecutive frames can lead to flicker or motion artifacts. | Train with temporal‑consistency losses; use 3‑D U‑Net or DiT architectures that share weights across time; add a motion‑vector or optical‑flow conditioning. |
# | **Long‑range dependencies** | Capturing global motion (e.g., a person walking across a room) requires the model to remember context over many frames. | Hierarchical sampling (coarse‑to‑fine in time), memory‑efficient transformers (DiT), or sparse conditioning (e.g., key‑frames). |
# | **Memory & compute cost** | Full‑resolution, high‑framerate videos require huge GPU memory for a single forward pass. | Multi‑scale generation (generate low‑res, then upscale), progressive upsampling, or diffusion in a compressed latent space. |
# | **Sampling speed** | Diffusion needs many denoising steps (often 1000+). | Use fewer steps with knowledge distillation, DDIM/PLMS shortcuts, or continuous diffusion models that allow larger step sizes. |
# | **Data scarcity** | High‑quality video datasets are smaller and more expensive than image datasets. | Data augmentation (temporal jittering, frame shuffling), transfer learning from image diffusion models, or synthetic data generation. |
# | **Control and editing** | Users often want to impose motion constraints, edit specific frames, or blend multiple videos. | ControlNet‑style conditioning, ControlVideo, or “in‑painting” diffusion that replaces a subset of frames while keeping the rest fixed. |
# | **Evaluation metrics** | Image‑based metrics (FID, LPIPS) don’t capture temporal quality. | Temporal FID, Fréchet Video Distance (FVD), or human perceptual studies. |
#
# ---
#
# **Bottom line**
# An agent loop in diffusion video generation is the iterative denoising cycle that can be conditioned on prior frames, text, or control signals. The main challenges stem from the sheer size of video tensors, the need for temporal coherence, limited data, and the computational burden of running many denoising steps. Researchers mitigate these by operating in latent spaces, designing 3‑D or transformer‑based architectures, using hierarchical or sparse conditioning, and applying efficient sampling schedules.
